# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
vgg19 = load_model("fakelogo.h5")

# %%
import numpy as np

# %%
def resize_image(image, size=(256, 256)):
    return tensorflow.image.resize(image, size)

# %%
# testing 1

img = image.load_img('/workspaces/SI-GuidedProject-592815-1697551698/Project Development Phase/genLogoOutput/PayPal/000001.jpg',target_size =(224,224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x,axis = 0)
pred =np.argmax(vgg19.predict(x))
op = ['Adidas', 'Amazon','Android', 'Apple','Ariel', 'Bic','BMW', 'Burger King', 'Cadbury', 'Chevrolet', 'Chrome', 'Coca Cola', 'Cowbell', 'Dominos', 'Fila','Gillet','Google', 'Goya oil', 'Guinness', 'Heinz', 'Honda','Hp', 'Huawei', 'Instagram', 'Kfc', 'Krisspy Kreme', 'Lays', 'Levis', 'Lg', 'Lipton', 'Mars', 'Marvel', 'McDonald', 'Mercedes Benz', 'Microsoft', 'MnM', 'Mtn', 'Mtn dew', 'NASA','Nescafe', 'Nestle', 'Nestle milo','Netflix',  'Nike', 'Nutella', 'Oral b','Oreo','Pay pal','Peak milk' 'Pepsi', 'PlayStation', 'Pringles', 'Puma','Reebok', 'Rolex', 'Samsung', 'Sprite', 'Starbucks','Tesla', 'Tiktok',  'Twitter', 'YouTube', 'Zara']
op[pred]
# Out:
# 1/1 [==============================] - 0s 457ms/step
# 'Adidas'

# %%
#Testing 2

img = image.load_img('/workspaces/SI-GuidedProject-592815-1697551698/Project Development Phase/output/Amazon/000001.jpg',target_size =(224,224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x,axis = 0)
pred =np.argmax(vgg19.predict(x))
op = ['Adidas', 'Amazon','Android', 'Apple','Ariel', 'Bic','BMW', 'Burger King', 'Cadbury', 'Chevrolet', 'Chrome', 'Coca Cola', 'Cowbell', 'Dominos', 'Fila','Gillet','Google', 'Goya oil', 'Guinness', 'Heinz', 'Honda','Hp', 'Huawei', 'Instagram', 'Kfc', 'Krisspy Kreme', 'Lays', 'Levis', 'Lg', 'Lipton', 'Mars', 'Marvel', 'McDonald', 'Mercedes Benz', 'Microsoft', 'MnM', 'Mtn', 'Mtn dew', 'NASA','Nescafe', 'Nestle', 'Nestle milo','Netflix',  'Nike', 'Nutella', 'Oral b','Oreo','Pay pal','Peak milk' 'Pepsi', 'PlayStation', 'Pringles', 'Puma','Reebok', 'Rolex', 'Samsung', 'Sprite', 'Starbucks','Tesla', 'Tiktok',  'Twitter', 'YouTube', 'Zara']
op[pred]
# Out:
# 1/1 [==============================] - 0s 490ms/step
# 'Amazon'

# %%
#Testing 2

img = image.load_img('/workspaces/SI-GuidedProject-592815-1697551698/Project Development Phase/output/Cowbell/000001.jpg',target_size =(224,224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x,axis = 0)
pred =np.argmax(vgg19.predict(x))
op = ['Adidas', 'Amazon','Android', 'Apple','Ariel', 'Bic','BMW', 'Burger King', 'Cadbury', 'Chevrolet', 'Chrome', 'Coca Cola', 'Cowbell', 'Dominos', 'Fila','Gillet','Google', 'Goya oil', 'Guinness', 'Heinz', 'Honda','Hp', 'Huawei', 'Instagram', 'Kfc', 'Krisspy Kreme', 'Lays', 'Levis', 'Lg', 'Lipton', 'Mars', 'Marvel', 'McDonald', 'Mercedes Benz', 'Microsoft', 'MnM', 'Mtn', 'Mtn dew', 'NASA','Nescafe', 'Nestle', 'Nestle milo','Netflix',  'Nike', 'Nutella', 'Oral b','Oreo','Pay pal','Peak milk' 'Pepsi', 'PlayStation', 'Pringles', 'Puma','Reebok', 'Rolex', 'Samsung', 'Sprite', 'Starbucks','Tesla', 'Tiktok',  'Twitter', 'YouTube', 'Zara']
op[pred]
# Out:
# 1/1 [==============================] - 0s 453ms/step
# 'Cowbell'

# %%
#Testing 3

img = image.load_img('/workspaces/SI-GuidedProject-592815-1697551698/Project Development Phase/output/Lipton/000001.jpg',target_size =(224,224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x,axis = 0)
pred =np.argmax(vgg19.predict(x))
op = ['Adidas', 'Amazon','Android', 'Apple','Ariel', 'Bic','BMW', 'Burger King', 'Cadbury', 'Chevrolet', 'Chrome', 'Coca Cola', 'Cowbell', 'Dominos', 'Fila','Gillet','Google', 'Goya oil', 'Guinness', 'Heinz', 'Honda','Hp', 'Huawei', 'Instagram', 'Kfc', 'Krisspy Kreme', 'Lays', 'Levis', 'Lg', 'Lipton', 'Mars', 'Marvel', 'McDonald', 'Mercedes Benz', 'Microsoft', 'MnM', 'Mtn', 'Mtn dew', 'NASA','Nescafe', 'Nestle', 'Nestle milo','Netflix',  'Nike', 'Nutella', 'Oral b','Oreo','Pay pal','Peak milk' 'Pepsi', 'PlayStation', 'Pringles', 'Puma','Reebok', 'Rolex', 'Samsung', 'Sprite', 'Starbucks','Tesla', 'Tiktok',  'Twitter', 'YouTube', 'Zara']
op[pred]
# Out:
# 1/1 [==============================] - 1s 504ms/step
# 'Lipton'

# %%
#Testing 4

img = image.load_img('/workspaces/SI-GuidedProject-592815-1697551698/Project Development Phase/output/Oreo/000003.jpg',target_size =(224,224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x,axis = 0)
pred =np.argmax(vgg19.predict(x))
op = ['Adidas', 'Amazon','Android', 'Apple','Ariel', 'Bic','BMW', 'Burger King', 'Cadbury', 'Chevrolet', 'Chrome', 'Coca Cola', 'Cowbell', 'Dominos', 'Fila','Gillet','Google', 'Goya oil', 'Guinness', 'Heinz', 'Honda','Hp', 'Huawei', 'Instagram', 'Kfc', 'Krisspy Kreme', 'Lays', 'Levis', 'Lg', 'Lipton', 'Mars', 'Marvel', 'McDonald', 'Mercedes Benz', 'Microsoft', 'MnM', 'Mtn', 'Mtn dew', 'NASA','Nescafe', 'Nestle', 'Nestle milo','Netflix',  'Nike', 'Nutella', 'Oral b','Oreo','Pay pal','Peak milk' 'Pepsi', 'PlayStation', 'Pringles', 'Puma','Reebok', 'Rolex', 'Samsung', 'Sprite', 'Starbucks','Tesla', 'Tiktok',  'Twitter', 'YouTube', 'Zara']
op[pred]
# Out:
# 1/1 [==============================] - 0s 481ms/step
# 'Oreo'

# %%
#Testing 5

img = image.load_img('/workspaces/SI-GuidedProject-592815-1697551698/Project Development Phase/output/YouTube/000003.jpg',target_size =(224,224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x,axis = 0)
pred =np.argmax(vgg19.predict(x))
op = ['Adidas', 'Amazon','Android', 'Apple','Ariel', 'Bic','BMW', 'Burger King', 'Cadbury', 'Chevrolet', 'Chrome', 'Coca Cola', 'Cowbell', 'Dominos', 'Fila','Gillet','Google', 'Goya oil', 'Guinness', 'Heinz', 'Honda','Hp', 'Huawei', 'Instagram', 'Kfc', 'Krisspy Kreme', 'Lays', 'Levis', 'Lg', 'Lipton', 'Mars', 'Marvel', 'McDonald', 'Mercedes Benz', 'Microsoft', 'MnM', 'Mtn', 'Mtn dew', 'NASA','Nescafe', 'Nestle', 'Nestle milo','Netflix',  'Nike', 'Nutella', 'Oral b','Oreo','Pay pal','Peak milk', 'Pepsi', 'PlayStation', 'Pringles', 'Puma','Reebok', 'Rolex', 'Samsung', 'Sprite', 'Starbucks','Tesla', 'Tiktok',  'Twitter', 'YouTube', 'Zara']
op[pred]
# Out:
# 1/1 [==============================] - 0s 457ms/step
# 'YouTube'

# %%
#Testing 6

img = image.load_img('/workspaces/SI-GuidedProject-592815-1697551698/Project Development Phase/output/Sprite/000002.jpg',target_size =(224,224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x,axis = 0)
pred =np.argmax(vgg19.predict(x))
op = ['Adidas', 'Amazon','Android', 'Apple','Ariel', 'Bic','BMW', 'Burger King', 'Cadbury', 'Chevrolet', 'Chrome', 'Coca Cola', 'Cowbell', 'Dominos', 'Fila','Gillet','Google', 'Goya oil', 'Guinness', 'Heinz', 'Honda','Hp', 'Huawei', 'Instagram', 'Kfc', 'Krisspy Kreme', 'Lays', 'Levis', 'Lg', 'Lipton', 'Mars', 'Marvel', 'McDonald', 'Mercedes Benz', 'Microsoft', 'MnM', 'Mtn', 'Mtn dew', 'NASA','Nescafe', 'Nestle', 'Nestle milo','Netflix',  'Nike', 'Nutella', 'Oral b','Oreo','Pay pal','Peak milk', 'Pepsi', 'PlayStation', 'Pringles', 'Puma','Reebok', 'Rolex', 'Samsung', 'Sprite', 'Starbucks','Tesla', 'Tiktok',  'Twitter', 'YouTube', 'Zara']
op[pred]
# Out:
# 1/1 [==============================] - 0s 473ms/step
# 'Sprite'

# %%
#Testing 7

img = image.load_img('/workspaces/SI-GuidedProject-592815-1697551698/Project Development Phase/genLogoOutput/Nestle milo/scal_000001.jpg',target_size =(224,224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x,axis = 0)
pred =np.argmax(vgg19.predict(x))
op = ['Adidas', 'Amazon','Android', 'Apple','Ariel', 'Bic','BMW', 'Burger King', 'Cadbury', 'Chevrolet', 'Chrome', 'Coca Cola', 'Cowbell', 'Dominos', 'Fila','Gillet','Google', 'Goya oil', 'Guinness', 'Heinz', 'Honda','Hp', 'Huawei', 'Instagram', 'Kfc', 'Krisspy Kreme', 'Lays', 'Levis', 'Lg', 'Lipton', 'Mars', 'Marvel', 'McDonald', 'Mercedes Benz', 'Microsoft', 'MnM', 'Mtn', 'Mtn dew', 'NASA','Nescafe', 'Nestle', 'Nestle milo','Netflix',  'Nike', 'Nutella', 'Oral b','Oreo','Pay pal','Peak milk', 'Pepsi', 'PlayStation', 'Pringles', 'Puma','Reebok', 'Rolex', 'Samsung', 'Sprite', 'Starbucks','Tesla', 'Tiktok',  'Twitter', 'YouTube', 'Zara']
op[pred]
# Out:
# 1/1 [==============================] - 1s 562ms/step
# 'Nestle milo'

# %%
#Testing 8

img = image.load_img('/workspaces/SI-GuidedProject-592815-1697551698/Project Development Phase/genLogoOutput/PlayStation/scal_000002.jpg',target_size =(224,224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x,axis = 0)
pred =np.argmax(vgg19.predict(x))
op = ['Adidas', 'Amazon','Android', 'Apple','Ariel', 'Bic','BMW', 'Burger King', 'Cadbury', 'Chevrolet', 'Chrome', 'Coca Cola', 'Cowbell', 'Dominos', 'Fila','Gillet','Google', 'Goya oil', 'Guinness', 'Heinz', 'Honda','Hp', 'Huawei', 'Instagram', 'Kfc', 'Krisspy Kreme', 'Lays', 'Levis', 'Lg', 'Lipton', 'Mars', 'Marvel', 'McDonald', 'Mercedes Benz', 'Microsoft', 'MnM', 'Mtn', 'Mtn dew', 'NASA','Nescafe', 'Nestle', 'Nestle milo','Netflix',  'Nike', 'Nutella', 'Oral b','Oreo','Pay pal','Peak milk', 'Pepsi', 'PlayStation', 'Pringles', 'Puma','Reebok', 'Rolex', 'Samsung', 'Sprite', 'Starbucks','Tesla', 'Tiktok',  'Twitter', 'YouTube', 'Zara']
op[pred]
# Out:
# 1/1 [==============================] - 0s 479ms/step
# 'PlayStation'

# %%
#Testing 9

img = image.load_img('/workspaces/SI-GuidedProject-592815-1697551698/Project Development Phase/output/Google/000003.jpg',target_size =(224,224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x,axis = 0)
pred =np.argmax(vgg19.predict(x))
op = ['Adidas', 'Amazon','Android', 'Apple','Ariel', 'Bic','BMW', 'Burger King', 'Cadbury', 'Chevrolet', 'Chrome', 'Coca Cola', 'Cowbell', 'Dominos', 'Fila','Gillet','Google', 'Goya oil', 'Guinness', 'Heinz', 'Honda','Hp', 'Huawei', 'Instagram', 'Kfc', 'Krisspy Kreme', 'Lays', 'Levis', 'Lg', 'Lipton', 'Mars', 'Marvel', 'McDonald', 'Mercedes Benz', 'Microsoft', 'MnM', 'Mtn', 'Mtn dew', 'NASA','Nescafe', 'Nestle', 'Nestle milo','Netflix',  'Nike', 'Nutella', 'Oral b','Oreo','Pay pal','Peak milk', 'Pepsi', 'PlayStation', 'Pringles', 'Puma','Reebok', 'Rolex', 'Samsung', 'Sprite', 'Starbucks','Tesla', 'Tiktok',  'Twitter', 'YouTube', 'Zara']
op[pred]
# Out:
# 1/1 [==============================] - 1s 503ms/step
# 'Google'

# %%
#Testing 10

img = image.load_img('/workspaces/SI-GuidedProject-592815-1697551698/Project Development Phase/output/Burger King/000004.jpg',target_size =(224,224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x,axis = 0)
pred =np.argmax(vgg19.predict(x))
op = ['Adidas', 'Amazon','Android', 'Apple','Ariel', 'Bic','BMW', 'Burger King', 'Cadbury', 'Chevrolet', 'Chrome', 'Coca Cola', 'Cowbell', 'Dominos', 'Fila','Gillet','Google', 'Goya oil', 'Guinness', 'Heinz', 'Honda','Hp', 'Huawei', 'Instagram', 'Kfc', 'Krisspy Kreme', 'Lays', 'Levis', 'Lg', 'Lipton', 'Mars', 'Marvel', 'McDonald', 'Mercedes Benz', 'Microsoft', 'MnM', 'Mtn', 'Mtn dew', 'NASA','Nescafe', 'Nestle', 'Nestle milo','Netflix',  'Nike', 'Nutella', 'Oral b','Oreo','Pay pal','Peak milk', 'Pepsi', 'PlayStation', 'Pringles', 'Puma','Reebok', 'Rolex', 'Samsung', 'Sprite', 'Starbucks','Tesla', 'Tiktok',  'Twitter', 'YouTube', 'Zara']
op[pred]
# Out:
# 1/1 [==============================] - 0s 462ms/step
# 'Burger King'
